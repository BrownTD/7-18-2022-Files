# %%
import pandas as pd
from pathlib import Path

# %%
list_of_numbers = [12, 0, 55, 12, 12]

# %%
type(list_of_numbers)
# Out:
# list

# %%
type(list_of_numbers[0])
# Out:
# int

# %%
series_of_numbers = pd.Series(list_of_numbers)
print (series_of_numbers)
# Out:
# 0    12
# 1     0
# 2    55
# 3    12
# 4    12
# dtype: int64

# %%
series_of_numbers.dtypes
# Out:
# dtype('int64')

# %%
series_of_numbers.iloc[0]
# Out:
# 12

# %%
series_of_numbers[0]
# Out:
# 12

# %%
# Get the count of the number of times a value occurs in a Series
series_of_numbers.value_counts()
# Out:
# 12    3
# 0     1
# 55    1
# dtype: int64

# %%
# Get the unique values of a Series
series_of_numbers.unique()
# Out:
# array([12,  0, 55], dtype=int64)

# %%
# A function to triple any value
def triple_value(some_value):
    return some_value * 3

# Apply triple value to series_of_numbers
series_of_numbers.apply(triple_value)
# Out:
# 0     36
# 1      0
# 2    165
# 3     36
# 4     36
# dtype: int64

# %%
# A dictionary of stock values
stock_values = {"MSFT": 160, "AAPL": "75.09", "TWTR": 32.3}

# %%
# Create series object from dictionary
stock_series = pd.Series(stock_values)

print(stock_series)
# Out:
# MSFT      160
# AAPL    75.09
# TWTR     32.3
# dtype: object

# %%
# Return the data type of the elements in the series
stock_series.dtypes
# Out:
# dtype('O')

# %%
# Apply float to each item in the series
stock_series = stock_series.apply(float)

# %%
# Return the data type of the elements in the series
stock_series.dtypes
print(stock_series)
# Out:
# MSFT    160.00
# AAPL     75.09
# TWTR     32.30
# dtype: float64

# %%
# Access value at index location 0 using iloc
print(stock_series.iloc[0])

# Access value at index location 0 using list syntax
print(stock_series[0])

# Access value at index MSFT
print(stock_series["MSFT"])
# Out:
# 160.0
# 160.0
# 160.0

# %%
# Create a new stock series for google stock. The dictionary is passed in directly.
google_stock_series = pd.Series({"GOOGL": 1754.40})
google_stock_series
# Out:
# GOOGL    1754.4
# dtype: float64

# %%
# Create a new stock series for google stock. The dictionary is passed in directly.
google_stock_series = pd.Series({"GOOGL": 1754.40})
google_stock_series
print(stock_series)
# Out:
# MSFT    160.00
# AAPL     75.09
# TWTR     32.30
# dtype: float64

# %%
stock_series.append(google_stock_series)
print(stock_series)
# Out:
# MSFT    160.00
# AAPL     75.09
# TWTR     32.30
# dtype: float64
# C:\Users\Nbrown85\AppData\Local\Temp\2\ipykernel_13000\57593688.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock_series.append(google_stock_series)

# %%
stock_series = stock_series.append(google_stock_series)

print(stock_series)
# Out:
# MSFT      160.00
# AAPL       75.09
# TWTR       32.30
# GOOGL    1754.40
# dtype: float64
# C:\Users\Nbrown85\AppData\Local\Temp\2\ipykernel_13000\117035063.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock_series = stock_series.append(google_stock_series)

# %%
# Drop MSFT in-place
stock_series.drop("MSFT", inplace=True)

print(stock_series)
# Out:
# AAPL       75.09
# TWTR       32.30
# GOOGL    1754.40
# dtype: float64

# %%
# Update using list syntax
stock_series[1] = 35

print(stock_series)
# Out:
# AAPL       75.09
# TWTR       35.00
# GOOGL    1754.40
# dtype: float64

# %%
print(stock_series)
# Out:
# AAPL       75.09
# TWTR       35.00
# GOOGL    1754.40
# dtype: float64

# %%
# Update using named index label
stock_series["AAPL"] = 50

print(stock_series)
# Out:
# AAPL       50.0
# TWTR       35.0
# GOOGL    1754.4
# dtype: float64

# %%
# Print prices
for price in stock_series:
    print(price)
# Out:
# 50.0
# 35.0
# 1754.4

# %%
for symbol, price in stock_series.items():
    print(f"{symbol} - {price}")
# Out:
# AAPL - 50.0
# TWTR - 35.0
# GOOGL - 1754.4

# %%
# Create two series
opening_prices = pd.Series(
    {"MSFT": 160.32, "AAPL": 75.11, "TWTR": 32.52}, name="Opening Price"
)

closing_prices = pd.Series(
    {"MSFT": 158.23, "AAPL": 77.65, "TWTR": 33.08}, name="Closing Price"
)

print(opening_prices)
# Out:
# MSFT    160.32
# AAPL     75.11
# TWTR     32.52
# Name: Opening Price, dtype: float64

# %%
# Create DataFrame
prices_df = pd.DataFrame(data=[opening_prices, closing_prices])

# Show DataFrame
prices_df
# Out:
#                  MSFT   AAPL   TWTR
# Opening Price  160.32  75.11  32.52
# Closing Price  158.23  77.65  33.08

# %%
# Transpose prices_df
prices_df.T
# Out:
#       Opening Price  Closing Price
# MSFT         160.32         158.23
# AAPL          75.11          77.65
# TWTR          32.52          33.08

# %%
# Save T output to prices_df
prices_df = prices_df.T

# Show DataFrame
prices_df
# Out:
#       Opening Price  Closing Price
# MSFT         160.32         158.23
# AAPL          75.11          77.65
# TWTR          32.52          33.08

# %%
# Access the Opening Price column
prices_df["Opening Price"]
# Out:
# MSFT    160.32
# AAPL     75.11
# TWTR     32.52
# Name: Opening Price, dtype: float64

# %%
# Check type of column
type(prices_df["Opening Price"])
# Out:
# pandas.core.series.Series

# %%
# Retrieve AAPL opening price by location
prices_df["Opening Price"][1]
# Out:
# 75.11

# %%
# Retrieve the MSFT row
prices_df.loc["MSFT"]
# Out:
# Opening Price    160.32
# Closing Price    158.23
# Name: MSFT, dtype: float64

# %%
# Check type
type(prices_df.loc["MSFT"])
# Out:
# pandas.core.series.Series

# %%
# Retrieve MSFT closing price by key
prices_df.loc["MSFT"]["Closing Price"]
# Out:
# 158.23

# %%
# Retrieve MSFT closing price by location
prices_df.loc["MSFT"][1]
# Out:
# 158.23

# %%
# Dictionary of temperature values
daily_temperature_range = {
    "Monday": [50, 75],
    "Tuesday": [52, 73],
    "Wednesday": [53, 73],
    "Thursday": [55, 80],
    "Friday": [56, 79],
    "Saturday": [55, 81],
    "Sunday": [55, 80],
}

# %%
# Create DataFrame
temperature_df = pd.DataFrame(data=daily_temperature_range, index=["Low", "High"])

# Show DataFrame
temperature_df
# Out:
#       Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# Low       50       52         53        55      56        55      55
# High      75       73         73        80      79        81      80

# %%
# DataFrame transposition
temperature_df = temperature_df.T

# Show the DataFrame
temperature_df
# Out:
#            Low  High
# Monday      50    75
# Tuesday     52    73
# Wednesday   53    73
# Thursday    55    80
# Friday      56    79
# Saturday    55    81
# Sunday      55    80

# %%
# Check type
type(temperature_df["Low"])
# Out:
# pandas.core.series.Series

# %%
# Check type
type(temperature_df.loc["Monday"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# A Freinds DataFrame Activity 7/11/2022 Class Activity

# %%
 #A Friends DataFrame Activity
locations={
   "Andrew": "Tampa",
   "Priya": "Charlotte"
    }
years_of_experience= {"Andrew": 5, 
"Priya": 2}

technology_used={
  "Andrew": "Meridian",
"Priya": "PeopleSoft"
}

# %%
series_locations= pd.Series(locations)
series_years_of_experiecne= pd.Series(years_of_experience)
series_technology_used= pd.Series(technology_used)

# %%
friends_data_df= pd.DataFrame(data= [series_locations, series_years_of_experiecne, series_technology_used,], index=["Location", "Experience (Yrs)", "Unique Software"])
friends_data_df
# Out:
#                     Andrew       Priya
# Location             Tampa   Charlotte
# Experience (Yrs)         5           2
# Unique Software   Meridian  PeopleSoft

# %%
friends_data_df=friends_data_df.T

# %%
friends_data_df
# Out:
#          Location Experience (Yrs) Unique Software
# Andrew      Tampa                5        Meridian
# Priya   Charlotte                2      PeopleSoft

# %%
my_classmates= {"Andrew": ["Tampa", 5, "Meridian"], 
"Priya": ["Charlotte", 2, "PeopleSoft"]
}

my_classmates_df= pd.DataFrame(data=my_classmates, index=["City", "Software Experience", "Technologies Used"])
print(my_classmates_df)
# Out:
#                        Andrew       Priya
# City                    Tampa   Charlotte
# Software Experience         5           2
# Technologies Used    Meridian  PeopleSoft

# %%
my_classmates_df=my_classmates_df.T
print(my_classmates_df)
# Out:
#              City Software Experience Technologies Used
# Andrew      Tampa                   5          Meridian
# Priya   Charlotte                   2        PeopleSoft

# %%
my_classmates_df["City"]
# Out:
# Andrew        Tampa
# Priya     Charlotte
# Name: City, dtype: object

# %%
my_classmates_df["Software Experience"].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of Andrew    5
# Priya     2
# Name: Software Experience, dtype: object>

# %%
my_classmates_df["Software Experience"][1] = 6

# %%
print(my_classmates_df)
# Out:
#              City Software Experience Technologies Used
# Andrew      Tampa                   5          Meridian
# Priya   Charlotte                   6        PeopleSoft

# %%
csvpath = Path("customers.csv")
customer_dataframe = pd.read_csv(csvpath)
customer_dataframe.head()
# Out:
#           FullName                     Email                  Address    Zip  \
# 0  Altha Frederick  unhideable1966@gmail.com  67 John Maher Extension  31353
# 1  Nickolas Harvey   allgood1803@outlook.com        1200 Madera Plaza   1922
# 2  Jesusita Kinney    satsumas1954@yahoo.com         943 Gibb Highway  41535
# 3      Mose Gordon    antifowl1875@gmail.com          1073 Fell Trace  16098
# 4  Cesar Valentine  acetaminol1979@yahoo.com   805 Marshall Promenade  99895
#
#             CreditCard  Balance
# 0  2524 2317 2139 4751    21511
# 1  4756 0997 9568 1329    13850
# 2    3717 863466 48574    21254
# 3  5413 1700 6989 2835     5221
# 4  5173 4883 9215 4743     8300

# %%
# Display column names
customer_dataframe.columns
# Out:
# Index(['FullName', 'Email', 'Address', 'Zip', 'CreditCard', 'Balance'], dtype='object')

# %%
# Rewrite the column names
columns = ["Full Name", "Email", "Address", "Zip Code", "Credit Card Number", "Account Balance"]
customer_dataframe.columns = columns
customer_dataframe.head()
# Out:
#          Full Name                     Email                  Address  \
# 0  Altha Frederick  unhideable1966@gmail.com  67 John Maher Extension
# 1  Nickolas Harvey   allgood1803@outlook.com        1200 Madera Plaza
# 2  Jesusita Kinney    satsumas1954@yahoo.com         943 Gibb Highway
# 3      Mose Gordon    antifowl1875@gmail.com          1073 Fell Trace
# 4  Cesar Valentine  acetaminol1979@yahoo.com   805 Marshall Promenade
#
#    Zip Code   Credit Card Number  Account Balance
# 0     31353  2524 2317 2139 4751            21511
# 1      1922  4756 0997 9568 1329            13850
# 2     41535    3717 863466 48574            21254
# 3     16098  5413 1700 6989 2835             5221
# 4     99895  5173 4883 9215 4743             8300

# %%
customer_dataframe = customer_dataframe.rename(columns={
    "Full Name": "full_name",
    "Credit Card Number": "credit_card_number"
})

customer_dataframe.head()
# Out:
#          full_name                     Email                  Address  \
# 0  Altha Frederick  unhideable1966@gmail.com  67 John Maher Extension
# 1  Nickolas Harvey   allgood1803@outlook.com        1200 Madera Plaza
# 2  Jesusita Kinney    satsumas1954@yahoo.com         943 Gibb Highway
# 3      Mose Gordon    antifowl1875@gmail.com          1073 Fell Trace
# 4  Cesar Valentine  acetaminol1979@yahoo.com   805 Marshall Promenade
#
#    Zip Code   credit_card_number  Account Balance
# 0     31353  2524 2317 2139 4751            21511
# 1      1922  4756 0997 9568 1329            13850
# 2     41535    3717 863466 48574            21254
# 3     16098  5413 1700 6989 2835             5221
# 4     99895  5173 4883 9215 4743             8300

# %%
customer_dataframe = customer_dataframe[['credit_card_number', 'Account Balance', 'full_name', 'Email', 'Address', 'Zip Code']]
customer_dataframe.head()
# Out:
#     credit_card_number  Account Balance        full_name  \
# 0  2524 2317 2139 4751            21511  Altha Frederick
# 1  4756 0997 9568 1329            13850  Nickolas Harvey
# 2    3717 863466 48574            21254  Jesusita Kinney
# 3  5413 1700 6989 2835             5221      Mose Gordon
# 4  5173 4883 9215 4743             8300  Cesar Valentine
#
#                       Email                  Address  Zip Code
# 0  unhideable1966@gmail.com  67 John Maher Extension     31353
# 1   allgood1803@outlook.com        1200 Madera Plaza      1922
# 2    satsumas1954@yahoo.com         943 Gibb Highway     41535
# 3    antifowl1875@gmail.com          1073 Fell Trace     16098
# 4  acetaminol1979@yahoo.com   805 Marshall Promenade     99895

# %%
names = customer_dataframe["full_name"].str.split(" ", expand=True)
names.head()
# Out:
#           0          1
# 0     Altha  Frederick
# 1  Nickolas     Harvey
# 2  Jesusita     Kinney
# 3      Mose     Gordon
# 4     Cesar  Valentine

# %% [markdown]
# Indexing DataFrames

# %%
# Set the path
file_path = Path("loans.csv")

# Read in the CSV as a DataFrame
loans_csv = pd.read_csv(file_path)

# %%
loans_csv
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  \
# 0           10000        10000          10000.0  36 months    0.1033
# 1            4000         4000           4000.0  36 months    0.2340
# 2            5000         5000           5000.0  36 months    0.1797
# 3            9600         9600           9600.0  36 months    0.1298
# 4            2500         2500           2500.0  36 months    0.1356
# ...           ...          ...              ...        ...       ...
# 128407      23000        23000          23000.0  36 months    0.1502
# 128408      10000        10000          10000.0  36 months    0.1502
# 128409       5000         5000           5000.0  36 months    0.1356
# 128410      10000        10000           9750.0  36 months    0.1106
# 128411      10000        10000          10000.0  36 months    0.1691
#
#         installment grade sub_grade             emp_title emp_length  \
# 0            324.23     B        B1                   NaN   < 1 year
# 1            155.68     E        E1              Security    3 years
# 2            180.69     D        D1        Administrative    6 years
# 3            323.37     B        B5                   NaN        NaN
# 4             84.92     C        C1                  Chef  10+ years
# ...             ...   ...       ...                   ...        ...
# 128407       797.53     C        C3        Tax Consultant  10+ years
# 128408       346.76     C        C3        security guard    5 years
# 128409       169.83     C        C1          Payoff Clerk  10+ years
# 128410       327.68     B        B3                   NaN        NaN
# 128411       356.08     C        C5  Key Accounts Manager    2 years
#
#        home_ownership  annual_inc verification_status issue_d  loan_status  \
# 0            MORTGAGE    280000.0        Not Verified  Dec-18      Current
# 1                RENT     90000.0     Source Verified  Dec-18      Current
# 2            MORTGAGE     59280.0     Source Verified  Dec-18      Current
# 3            MORTGAGE     35704.0        Not Verified  Dec-18      Current
# 4                RENT     55000.0        Not Verified  Dec-18      Current
# ...               ...         ...                 ...     ...          ...
# 128407       MORTGAGE     75000.0     Source Verified  Oct-18  Charged Off
# 128408       MORTGAGE     38000.0        Not Verified  Oct-18      Current
# 128409       MORTGAGE     35360.0        Not Verified  Oct-18      Current
# 128410           RENT     44400.0     Source Verified  Oct-18      Current
# 128411           RENT     80000.0        Not Verified  Oct-18      Current
#
#        pymnt_plan             purpose
# 0               n  debt_consolidation
# 1               n  debt_consolidation
# 2               n  debt_consolidation
# 3               n    home_improvement
# 4               n  debt_consolidation
# ...           ...                 ...
# 128407          n  debt_consolidation
# 128408          n  debt_consolidation
# 128409          n  debt_consolidation
# 128410          n         credit_card
# 128411          n               other
#
# [128412 rows x 17 columns]

# %%
# "Describe" summary statistics for all of the csv data
loans_csv.describe(include='all')
# Out:
#             loan_amnt    funded_amnt  funded_amnt_inv       term  \
# count   128412.000000  128412.000000    128412.000000     128412
# unique            NaN            NaN              NaN          2
# top               NaN            NaN              NaN  36 months
# freq              NaN            NaN              NaN      88179
# mean     15971.321021   15971.321021     15968.498166        NaN
# std      10150.384233   10150.384233     10152.168970        NaN
# min       1000.000000    1000.000000       725.000000        NaN
# 25%       8000.000000    8000.000000      8000.000000        NaN
# 50%      14000.000000   14000.000000     14000.000000        NaN
# 75%      21600.000000   21600.000000     21600.000000        NaN
# max      40000.000000   40000.000000     40000.000000        NaN
#
#              int_rate    installment   grade sub_grade emp_title emp_length  \
# count   128412.000000  128412.000000  128412    128412    107465     116708
# unique            NaN            NaN       7        35     43892         11
# top               NaN            NaN       A        A4   Teacher  10+ years
# freq              NaN            NaN   38011      9770      2090      38826
# mean         0.129302     463.259353     NaN       NaN       NaN        NaN
# std          0.050904     285.718256     NaN       NaN       NaN        NaN
# min          0.060000      30.480000     NaN       NaN       NaN        NaN
# 25%          0.084600     253.630000     NaN       NaN       NaN        NaN
# 50%          0.118000     382.905000     NaN       NaN       NaN        NaN
# 75%          0.161400     622.680000     NaN       NaN       NaN        NaN
# max          0.309900    1618.240000     NaN       NaN       NaN        NaN
#
#        home_ownership    annual_inc verification_status issue_d loan_status  \
# count          128412  1.284120e+05              128412  128412      128412
# unique              4           NaN                   3       3           7
# top          MORTGAGE           NaN        Not Verified  Oct-18     Current
# freq            63490           NaN               58350   46305      119540
# mean              NaN  8.279733e+04                 NaN     NaN         NaN
# std               NaN  1.082985e+05                 NaN     NaN         NaN
# min               NaN  0.000000e+00                 NaN     NaN         NaN
# 25%               NaN  4.705800e+04                 NaN     NaN         NaN
# 50%               NaN  6.800000e+04                 NaN     NaN         NaN
# 75%               NaN  9.900000e+04                 NaN     NaN         NaN
# max               NaN  9.757200e+06                 NaN     NaN         NaN
#
#        pymnt_plan             purpose
# count      128412              128412
# unique          1                  12
# top             n  debt_consolidation
# freq       128412               70603
# mean          NaN                 NaN
# std           NaN                 NaN
# min           NaN                 NaN
# 25%           NaN                 NaN
# 50%           NaN                 NaN
# 75%           NaN                 NaN
# max           NaN                 NaN

# %%
# Retrieve rows with index 0 up to but not including 5.
loans_csv.iloc[0:5]
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  installment  \
# 0      10000        10000          10000.0  36 months    0.1033       324.23
# 1       4000         4000           4000.0  36 months    0.2340       155.68
# 2       5000         5000           5000.0  36 months    0.1797       180.69
# 3       9600         9600           9600.0  36 months    0.1298       323.37
# 4       2500         2500           2500.0  36 months    0.1356        84.92
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     B        B5             NaN        NaN       MORTGAGE     35704.0
# 4     C        C1            Chef  10+ years           RENT     55000.0
#
#   verification_status issue_d loan_status pymnt_plan             purpose
# 0        Not Verified  Dec-18     Current          n  debt_consolidation
# 1     Source Verified  Dec-18     Current          n  debt_consolidation
# 2     Source Verified  Dec-18     Current          n  debt_consolidation
# 3        Not Verified  Dec-18     Current          n    home_improvement
# 4        Not Verified  Dec-18     Current          n  debt_consolidation

# %%
# Use iloc to find specific records
loans_csv.iloc[[0, 2, 4, 6]]
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  installment  \
# 0      10000        10000          10000.0  36 months    0.1033       324.23
# 2       5000         5000           5000.0  36 months    0.1797       180.69
# 4       2500         2500           2500.0  36 months    0.1356        84.92
# 6      23000        23000          23000.0  60 months    0.2089       620.81
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 4     C        C1            Chef  10+ years           RENT     55000.0
# 6     D        D4        Operator    5 years           RENT     68107.0
#
#   verification_status issue_d loan_status pymnt_plan             purpose
# 0        Not Verified  Dec-18     Current          n  debt_consolidation
# 2     Source Verified  Dec-18     Current          n  debt_consolidation
# 4        Not Verified  Dec-18     Current          n  debt_consolidation
# 6     Source Verified  Dec-18     Current          n  debt_consolidation

# %%
# Filter the DataFrame down to the following, keep all rows

#loan_amnt
#term
#int_rate
#purpose

filtered_df = loans_csv.iloc[:, [0, 3, 4, 16]]
filtered_df
# Out:
#         loan_amnt       term  int_rate             purpose
# 0           10000  36 months    0.1033  debt_consolidation
# 1            4000  36 months    0.2340  debt_consolidation
# 2            5000  36 months    0.1797  debt_consolidation
# 3            9600  36 months    0.1298    home_improvement
# 4            2500  36 months    0.1356  debt_consolidation
# ...           ...        ...       ...                 ...
# 128407      23000  36 months    0.1502  debt_consolidation
# 128408      10000  36 months    0.1502  debt_consolidation
# 128409       5000  36 months    0.1356  debt_consolidation
# 128410      10000  36 months    0.1106         credit_card
# 128411      10000  36 months    0.1691               other
#
# [128412 rows x 4 columns]

# %%
# Create a new dataframe filtering down to only loan amounts less than
# or equal to 5000
small_loan_size_df = filtered_df.loc[filtered_df['loan_amnt'] <= 5000].copy()
small_loan_size_df.head()
# Out:
#     loan_amnt       term  int_rate             purpose
# 1        4000  36 months    0.2340  debt_consolidation
# 2        5000  36 months    0.1797  debt_consolidation
# 4        2500  36 months    0.1356  debt_consolidation
# 16       3500  36 months    0.2089                 car
# 28       4000  36 months    0.1894      major_purchase

# %%
file_path= ("loans.csv")

loans_csv= pd.read_csv(file_path)

# %%
loans_csv
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  \
# 0           10000        10000          10000.0  36 months    0.1033
# 1            4000         4000           4000.0  36 months    0.2340
# 2            5000         5000           5000.0  36 months    0.1797
# 3            9600         9600           9600.0  36 months    0.1298
# 4            2500         2500           2500.0  36 months    0.1356
# ...           ...          ...              ...        ...       ...
# 128407      23000        23000          23000.0  36 months    0.1502
# 128408      10000        10000          10000.0  36 months    0.1502
# 128409       5000         5000           5000.0  36 months    0.1356
# 128410      10000        10000           9750.0  36 months    0.1106
# 128411      10000        10000          10000.0  36 months    0.1691
#
#         installment grade sub_grade             emp_title emp_length  \
# 0            324.23     B        B1                   NaN   < 1 year
# 1            155.68     E        E1              Security    3 years
# 2            180.69     D        D1        Administrative    6 years
# 3            323.37     B        B5                   NaN        NaN
# 4             84.92     C        C1                  Chef  10+ years
# ...             ...   ...       ...                   ...        ...
# 128407       797.53     C        C3        Tax Consultant  10+ years
# 128408       346.76     C        C3        security guard    5 years
# 128409       169.83     C        C1          Payoff Clerk  10+ years
# 128410       327.68     B        B3                   NaN        NaN
# 128411       356.08     C        C5  Key Accounts Manager    2 years
#
#        home_ownership  annual_inc verification_status issue_d  loan_status  \
# 0            MORTGAGE    280000.0        Not Verified  Dec-18      Current
# 1                RENT     90000.0     Source Verified  Dec-18      Current
# 2            MORTGAGE     59280.0     Source Verified  Dec-18      Current
# 3            MORTGAGE     35704.0        Not Verified  Dec-18      Current
# 4                RENT     55000.0        Not Verified  Dec-18      Current
# ...               ...         ...                 ...     ...          ...
# 128407       MORTGAGE     75000.0     Source Verified  Oct-18  Charged Off
# 128408       MORTGAGE     38000.0        Not Verified  Oct-18      Current
# 128409       MORTGAGE     35360.0        Not Verified  Oct-18      Current
# 128410           RENT     44400.0     Source Verified  Oct-18      Current
# 128411           RENT     80000.0        Not Verified  Oct-18      Current
#
#        pymnt_plan             purpose
# 0               n  debt_consolidation
# 1               n  debt_consolidation
# 2               n  debt_consolidation
# 3               n    home_improvement
# 4               n  debt_consolidation
# ...           ...                 ...
# 128407          n  debt_consolidation
# 128408          n  debt_consolidation
# 128409          n  debt_consolidation
# 128410          n         credit_card
# 128411          n               other
#
# [128412 rows x 17 columns]

# %%
loans_csv.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  installment  \
# 0      10000        10000          10000.0  36 months    0.1033       324.23
# 1       4000         4000           4000.0  36 months    0.2340       155.68
# 2       5000         5000           5000.0  36 months    0.1797       180.69
# 3       9600         9600           9600.0  36 months    0.1298       323.37
# 4       2500         2500           2500.0  36 months    0.1356        84.92
#
#   grade sub_grade       emp_title emp_length home_ownership  annual_inc  \
# 0     B        B1             NaN   < 1 year       MORTGAGE    280000.0
# 1     E        E1        Security    3 years           RENT     90000.0
# 2     D        D1  Administrative    6 years       MORTGAGE     59280.0
# 3     B        B5             NaN        NaN       MORTGAGE     35704.0
# 4     C        C1            Chef  10+ years           RENT     55000.0
#
#   verification_status issue_d loan_status pymnt_plan             purpose
# 0        Not Verified  Dec-18     Current          n  debt_consolidation
# 1     Source Verified  Dec-18     Current          n  debt_consolidation
# 2     Source Verified  Dec-18     Current          n  debt_consolidation
# 3        Not Verified  Dec-18     Current          n    home_improvement
# 4        Not Verified  Dec-18     Current          n  debt_consolidation

# %%
loans_csv.iloc[0:11]
# Out:
#     loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  installment  \
# 0       10000        10000          10000.0  36 months    0.1033       324.23
# 1        4000         4000           4000.0  36 months    0.2340       155.68
# 2        5000         5000           5000.0  36 months    0.1797       180.69
# 3        9600         9600           9600.0  36 months    0.1298       323.37
# 4        2500         2500           2500.0  36 months    0.1356        84.92
# 5       30000        30000          30000.0  60 months    0.1894       777.23
# 6       23000        23000          23000.0  60 months    0.2089       620.81
# 7       32075        32075          32075.0  60 months    0.1180       710.26
# 8        8000         8000           8000.0  36 months    0.2340       311.35
# 9       10000        10000          10000.0  60 months    0.1992       264.50
# 10      12000        12000          12000.0  60 months    0.1356       276.49
#
#    grade sub_grade           emp_title emp_length home_ownership  annual_inc  \
# 0      B        B1                 NaN   < 1 year       MORTGAGE    280000.0
# 1      E        E1            Security    3 years           RENT     90000.0
# 2      D        D1      Administrative    6 years       MORTGAGE     59280.0
# 3      B        B5                 NaN        NaN       MORTGAGE     35704.0
# 4      C        C1                Chef  10+ years           RENT     55000.0
# 5      D        D2         Postmaster   10+ years       MORTGAGE     90000.0
# 6      D        D4            Operator    5 years           RENT     68107.0
# 7      B        B4  Nursing Supervisor  10+ years       MORTGAGE    150000.0
# 8      E        E1             Manager  10+ years            OWN     43000.0
# 9      D        D3    Material Handler  10+ years       MORTGAGE     80000.0
# 10     C        C1                 NaN   < 1 year       MORTGAGE     40000.0
#
#    verification_status issue_d loan_status pymnt_plan             purpose
# 0         Not Verified  Dec-18     Current          n  debt_consolidation
# 1      Source Verified  Dec-18     Current          n  debt_consolidation
# 2      Source Verified  Dec-18     Current          n  debt_consolidation
# 3         Not Verified  Dec-18     Current          n    home_improvement
# 4         Not Verified  Dec-18     Current          n  debt_consolidation
# 5      Source Verified  Dec-18     Current          n  debt_consolidation
# 6      Source Verified  Dec-18     Current          n  debt_consolidation
# 7         Not Verified  Dec-18     Current          n         credit_card
# 8      Source Verified  Dec-18     Current          n  debt_consolidation
# 9         Not Verified  Dec-18     Current          n  debt_consolidation
# 10        Not Verified  Dec-18     Current          n  debt_consolidation

# %%
loans_csv.describe(include="all")
# Out:
#             loan_amnt    funded_amnt  funded_amnt_inv       term  \
# count   128412.000000  128412.000000    128412.000000     128412
# unique            NaN            NaN              NaN          2
# top               NaN            NaN              NaN  36 months
# freq              NaN            NaN              NaN      88179
# mean     15971.321021   15971.321021     15968.498166        NaN
# std      10150.384233   10150.384233     10152.168970        NaN
# min       1000.000000    1000.000000       725.000000        NaN
# 25%       8000.000000    8000.000000      8000.000000        NaN
# 50%      14000.000000   14000.000000     14000.000000        NaN
# 75%      21600.000000   21600.000000     21600.000000        NaN
# max      40000.000000   40000.000000     40000.000000        NaN
#
#              int_rate    installment   grade sub_grade emp_title emp_length  \
# count   128412.000000  128412.000000  128412    128412    107465     116708
# unique            NaN            NaN       7        35     43892         11
# top               NaN            NaN       A        A4   Teacher  10+ years
# freq              NaN            NaN   38011      9770      2090      38826
# mean         0.129302     463.259353     NaN       NaN       NaN        NaN
# std          0.050904     285.718256     NaN       NaN       NaN        NaN
# min          0.060000      30.480000     NaN       NaN       NaN        NaN
# 25%          0.084600     253.630000     NaN       NaN       NaN        NaN
# 50%          0.118000     382.905000     NaN       NaN       NaN        NaN
# 75%          0.161400     622.680000     NaN       NaN       NaN        NaN
# max          0.309900    1618.240000     NaN       NaN       NaN        NaN
#
#        home_ownership    annual_inc verification_status issue_d loan_status  \
# count          128412  1.284120e+05              128412  128412      128412
# unique              4           NaN                   3       3           7
# top          MORTGAGE           NaN        Not Verified  Oct-18     Current
# freq            63490           NaN               58350   46305      119540
# mean              NaN  8.279733e+04                 NaN     NaN         NaN
# std               NaN  1.082985e+05                 NaN     NaN         NaN
# min               NaN  0.000000e+00                 NaN     NaN         NaN
# 25%               NaN  4.705800e+04                 NaN     NaN         NaN
# 50%               NaN  6.800000e+04                 NaN     NaN         NaN
# 75%               NaN  9.900000e+04                 NaN     NaN         NaN
# max               NaN  9.757200e+06                 NaN     NaN         NaN
#
#        pymnt_plan             purpose
# count      128412              128412
# unique          1                  12
# top             n  debt_consolidation
# freq       128412               70603
# mean          NaN                 NaN
# std           NaN                 NaN
# min           NaN                 NaN
# 25%           NaN                 NaN
# 50%           NaN                 NaN
# 75%           NaN                 NaN
# max           NaN                 NaN

# %%
filtered_df= loans_csv.iloc[:, [0, 3, 4, 8, 11, 16]]
filtered_df.head()
# Out:
#    loan_amnt       term  int_rate       emp_title  annual_inc  \
# 0      10000  36 months    0.1033             NaN    280000.0
# 1       4000  36 months    0.2340        Security     90000.0
# 2       5000  36 months    0.1797  Administrative     59280.0
# 3       9600  36 months    0.1298             NaN     35704.0
# 4       2500  36 months    0.1356            Chef     55000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation

# %%
term_df= filtered_df.loc[filtered_df["term"]== "36 months"].copy()
term_df.head()
# Out:
#    loan_amnt       term  int_rate       emp_title  annual_inc  \
# 0      10000  36 months    0.1033             NaN    280000.0
# 1       4000  36 months    0.2340        Security     90000.0
# 2       5000  36 months    0.1797  Administrative     59280.0
# 3       9600  36 months    0.1298             NaN     35704.0
# 4       2500  36 months    0.1356            Chef     55000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation

# %%
term_df.loc[term_df['term'] == '36 months', 'term'] = '3 Years'
term_df.head()
# Out:
#    loan_amnt     term  int_rate       emp_title  annual_inc  \
# 0      10000  3 Years    0.1033             NaN    280000.0
# 1       4000  3 Years    0.2340        Security     90000.0
# 2       5000  3 Years    0.1797  Administrative     59280.0
# 3       9600  3 Years    0.1298             NaN     35704.0
# 4       2500  3 Years    0.1356            Chef     55000.0
#
#               purpose
# 0  debt_consolidation
# 1  debt_consolidation
# 2  debt_consolidation
# 3    home_improvement
# 4  debt_consolidation

# %%
term_df.isnull().sum()
# Out:
# loan_amnt         0
# term              0
# int_rate          0
# emp_title     15669
# annual_inc        0
# purpose           0
# dtype: int64

# %%
term_df= term_df.fillna("Unknown")
term_df
# Out:
#         loan_amnt     term  int_rate             emp_title  annual_inc  \
# 0           10000  3 Years    0.1033               Unknown    280000.0
# 1            4000  3 Years    0.2340              Security     90000.0
# 2            5000  3 Years    0.1797        Administrative     59280.0
# 3            9600  3 Years    0.1298               Unknown     35704.0
# 4            2500  3 Years    0.1356                  Chef     55000.0
# ...           ...      ...       ...                   ...         ...
# 128407      23000  3 Years    0.1502        Tax Consultant     75000.0
# 128408      10000  3 Years    0.1502        security guard     38000.0
# 128409       5000  3 Years    0.1356          Payoff Clerk     35360.0
# 128410      10000  3 Years    0.1106               Unknown     44400.0
# 128411      10000  3 Years    0.1691  Key Accounts Manager     80000.0
#
#                    purpose
# 0       debt_consolidation
# 1       debt_consolidation
# 2       debt_consolidation
# 3         home_improvement
# 4       debt_consolidation
# ...                    ...
# 128407  debt_consolidation
# 128408  debt_consolidation
# 128409  debt_consolidation
# 128410         credit_card
# 128411               other
#
# [88179 rows x 6 columns]

# %%
term_df.describe()
# Out:
#           loan_amnt      int_rate    annual_inc
# count  88179.000000  88179.000000  8.817900e+04
# mean   13279.580456      0.120610  8.043616e+04
# std     9479.610905      0.048955  1.109251e+05
# min     1000.000000      0.060000  0.000000e+00
# 25%     6000.000000      0.078400  4.500000e+04
# 50%    10000.000000      0.110600  6.500000e+04
# 75%    18000.000000      0.150200  9.500000e+04
# max    40000.000000      0.309900  9.000000e+06

# %%
term_df['emp_title'].value_counts()
# Out:
# Unknown                       15669
# Teacher                        1433
# Manager                        1207
# Registered Nurse                672
# Driver                          654
#                               ...
# mgt dept. embroider               1
# Financial Services Officer        1
# Office Manager/Controller         1
# Motorcoach Operator               1
# Key Accounts Manager              1
# Name: emp_title, Length: 31470, dtype: int64

# %%
term_df['purpose'].value_counts()
# Out:
# debt_consolidation    45456
# credit_card           24780
# other                  5836
# home_improvement       5446
# major_purchase         1795
# medical                1245
# car                     838
# small_business          828
# vacation                749
# house                   596
# moving                  547
# renewable_energy         63
# Name: purpose, dtype: int64

# %%
term_df.loc[term_df['annual_inc'] > 80000].describe()
# Out:
#           loan_amnt      int_rate    annual_inc
# count  29748.000000  29748.000000  2.974800e+04
# mean   18240.116142      0.114116  1.389634e+05
# std    10991.909117      0.048067  1.752361e+05
# min     1000.000000      0.060000  8.000100e+04
# 25%    10000.000000      0.075600  9.500000e+04
# 50%    15700.000000      0.104700  1.120000e+05
# 75%    25000.000000      0.144700  1.500000e+05
# max    40000.000000      0.309400  9.000000e+06

# %%
term_df.loc[term_df['annual_inc'] < 80000].describe()
# Out:
#           loan_amnt      int_rate    annual_inc
# count  56015.000000  56015.000000  56015.000000
# mean   10607.487727      0.124268  49372.805964
# std     7318.791900      0.049137  16669.098821
# min     1000.000000      0.060000      0.000000
# 25%     5000.000000      0.081900  37000.000000
# 50%     9600.000000      0.113100  50000.000000
# 75%    14000.000000      0.150200  62635.500000
# max    40000.000000      0.309900  79999.000000

# %%
market_data_df = pd.read_csv(Path('../Resources/market_data.csv'))
display(market_data_df.head())
market_data_df.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Nbrown85\Desktop\FinTech-Workspace\Jupyter Notebook Pandas and Series.ipynb Cell 85' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Nbrown85/Desktop/FinTech-Workspace/Jupyter%20Notebook%20Pandas%20and%20Series.ipynb#ch0000084?line=0'>1</a> market_data_df = pd.read_csv(Path('../Resources/market_data.csv'))
#       <a href='vscode-notebook-cell:/c%3A/Users/Nbrown85/Desktop/FinTech-Workspace/Jupyter%20Notebook%20Pandas%20and%20Series.ipynb#ch0000084?line=1'>2</a> display(market_data_df.head())
#       <a href='vscode-notebook-cell:/c%3A/Users/Nbrown85/Desktop/FinTech-Workspace/Jupyter%20Notebook%20Pandas%20and%20Series.ipynb#ch0000084?line=2'>3</a> market_data_df.info()
#
# File c:\Users\Nbrown85\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\Nbrown85\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Nbrown85\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File c:\Users\Nbrown85\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Nbrown85\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File c:\Users\Nbrown85\Anaconda3\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\Resources\\market_data.csv'

# %%
display(market_data_df.head())
market_data_df.info()
